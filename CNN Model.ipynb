# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten

# %% [markdown]
# # Data Preparation For the Convolutional Neural Network

# %%
Train_no=1
engine_id=50

df=pd.read_csv("Processed_Train_00{}.csv".format(Train_no))
df = df[df['ID']==engine_id]
df = df.drop(columns=['ID'])

df
# Out:
#       Cycle  SensorMeasure2  SensorMeasure3  SensorMeasure4  SensorMeasure7  \
# 9711      1          642.12         1582.50         1400.44          553.76
# 9712      2          642.62         1589.90         1404.14          554.52
# 9713      3          642.55         1582.75         1403.42          554.26
# 9714      4          642.61         1586.91         1403.46          554.56
# 9715      5          642.41         1589.70         1401.43          554.26
# ...     ...             ...             ...             ...             ...
# 9904    194          643.77         1604.93         1423.51          551.41
# 9905    195          643.33         1605.31         1434.87          551.25
# 9906    196          643.32         1602.26         1430.01          551.40
# 9907    197          643.73         1599.94         1432.87          551.18
# 9908    198          643.83         1608.20         1433.88          552.06
#
#       SensorMeasure8  SensorMeasure11  SensorMeasure12  SensorMeasure13  \
# 9711         2388.05            47.31           521.97          2388.08
# 9712         2388.02            47.31           522.27          2388.02
# 9713         2388.04            47.41           522.40          2388.04
# 9714         2388.05            47.46           522.25          2388.08
# 9715         2388.05            47.33           522.10          2388.00
# ...              ...              ...              ...              ...
# 9904         2388.18            48.16           519.85          2388.19
# 9905         2388.17            48.14           519.33          2388.21
# 9906         2388.19            48.24           519.88          2388.17
# 9907         2388.19            48.22           519.48          2388.20
# 9908         2388.20            48.01           520.00          2388.25
#
#       SensorMeasure15  SensorMeasure17  SensorMeasure20  SensorMeasure21  RUL
# 9711           8.4366              394            38.96          23.3947  197
# 9712           8.4211              394            38.91          23.4594  196
# 9713           8.3931              392            38.97          23.3230  195
# 9714           8.4286              393            38.91          23.3886  194
# 9715           8.4295              394            38.98          23.3340  193
# ...               ...              ...              ...              ...  ...
# 9904           8.5043              396            38.42          23.0543    4
# 9905           8.5352              395            38.45          23.0191    3
# 9906           8.5034              395            38.45          23.0379    2
# 9907           8.5241              397            38.52          23.0832    1
# 9908           8.5002              396            38.43          23.1086    0
#
# [198 rows x 14 columns]

# %%
# Scalling the DATA
scaler=MinMaxScaler()
df = scaler.fit_transform(df)
print('Shape of df for engine {}: '.format(engine_id),df.shape)
df
# Out:
# Shape of df for engine 50:  (198, 14)
# array([[0.        , 0.14222222, 0.19258561, ..., 0.78571429, 0.82617801,
#         1.        ],
#        [0.00507614, 0.36444444, 0.42507069, ..., 0.72619048, 0.96167539,
#         0.99492386],
#        [0.01015228, 0.33333333, 0.20043984, ..., 0.79761905, 0.67602094,
#         0.98984772],
#        ...,
#        [0.98984772, 0.67555556, 0.8133836 , ..., 0.17857143, 0.07895288,
#         0.01015228],
#        [0.99492386, 0.85777778, 0.74049639, ..., 0.26190476, 0.17382199,
#         0.00507614],
#        [1.        , 0.90222222, 1.        , ..., 0.1547619 , 0.22701571,
#         0.        ]])

# %%
# Getting into training shape with slidingwindow
features = df[:,0:-1]
target = df[:,-1]

target
# Out:
# array([1.        , 0.99492386, 0.98984772, 0.98477157, 0.97969543,
#        0.97461929, 0.96954315, 0.96446701, 0.95939086, 0.95431472,
#         [0.82617801]],
#
#        [[0.00507614],
#         [0.36444444],
#         [0.42507069],
#         [0.21022873],
#         [0.88829787],
#         [0.13043478],
#         [0.16216216],
#         [0.94230769],
#         [0.17857143],
#         [0.31553689],
#         [0.57142857],
#         [0.72619048],
#         [0.96167539]],
#
#        [[0.01015228],
#         [0.33333333],
#         [0.20043984],
#         [0.19172449],
#         [0.81914894],
#         [0.2173913 ],
#         [0.25225225],
#         [0.98397436],
#         [0.25      ],
#         [0.14757049],
#         [0.28571429],
#         [0.79761905],
#         [0.67602094]],
#
#        [[0.01522843],
#         [0.36      ],
#         [0.33113415],
#         [0.19275251],
#         [0.89893617],
#         [0.26086957],
#         [0.2972973 ],
#         [0.93589744],
#         [0.39285714],
#         [0.36052789],
#         [0.42857143],
#         [0.72619048],
#         [0.81340314]],
#
#        [[0.02030457],
#         [0.27111111],
#         [0.41878731],
#         [0.14058083],
#         [0.81914894],
#         [0.26086957],
#         [0.18018018],
#         [0.88782051],
#         [0.10714286],
#         [0.36592681],
#         [0.57142857],
#         [0.80952381],
#         [0.69905759]],
#
#        [[0.02538071],
#         [0.29333333],
#         [0.28180961],
#         [0.16628116],
#         [0.65159574],
#         [0.08695652],
#         [0.31531532],
#         [0.71474359],
#         [0.        ],
#         [0.23275345],
#         [0.14285714],
#         [0.67857143],
#         [0.62513089]],
#
#        [[0.03045685],
#         [0.25333333],
#         [0.26390198],
#         [0.16396813],
#         [0.72606383],
#         [0.34782609],
#         [0.15315315],
#         [0.72435897],
#         [0.25      ],
#         [0.17216557],
#         [0.42857143],
#         [0.88095238],
#         [0.83727749]],
#
#        [[0.03553299],
#         [0.25777778],
#         [0.29060635],
#         [0.13235672],
#         [0.78989362],
#         [0.2173913 ],
#         [0.22522523],
#         [0.95512821],
#         [0.5       ],
#         [0.47510498],
#         [0.28571429],
#         [0.69047619],
#         [0.78931937]],
#
#        [[0.04060914],
#         [0.32888889],
#         [0.16745209],
#         [0.05319969],
#         [0.66223404],
#         [0.2173913 ],
#         [0.21621622],
#         [0.91346154],
#         [0.39285714],
#         [0.25074985],
#         [0.42857143],
#         [0.77380952],
#         [0.7304712 ]],
#
#        [[0.04568528],
#         [0.23555556],
#         [0.29688973],
#         [0.        ],
#         [0.90425532],
#         [0.43478261],
#         [0.11711712],
#         [0.67307692],
#         [0.21428571],
#         [0.29034193],
#         [0.28571429],
#         [0.60714286],
#         [0.56795812]],
#
#        [[0.05076142],
#         [0.11111111],
#         [0.06566133],
#         [0.01207916],
#         [0.58510638],
#         [0.43478261],
#         [0.24324324],
#         [0.71794872],
#         [0.42857143],
#         [0.17636473],
#         [0.28571429],
#         [0.60714286],
#         [0.65005236]],
#
#        [[0.05583756],
#         [0.42666667],
#         [0.16085454],
#         [0.10845541],
#         [0.86170213],
#         [0.34782609],
#         [0.18918919],
#         [0.92948718],
#         [0.42857143],
#         [0.50569886],
#         [0.42857143],
#         [0.64285714],
#         [0.71308901]],
#
#        [[0.06091371],
#         [0.35555556],
#         [0.        ],
#         [0.0688769 ],
#         [0.5212766 ],
#         [0.34782609],
#         [0.24324324],
#         [0.81410256],
#         [0.35714286],
#         [0.19076185],
#         [0.42857143],
#         [0.6547619 ],
#         [0.64921466]],
#
#        [[0.06598985],
#         [0.06666667],
#         [0.38548539],
#         [0.27036751],
#         [0.65159574],
#         [0.26086957],
#         [0.27027027],
#         [0.77884615],
#         [0.28571429],
#         [0.23215357],
#         [0.14285714],
#         [0.77380952],
#         [0.7426178 ]],
#
#        [[0.07106599],
#         [0.17333333],
#         [0.3914546 ],
#         [0.09149319],
#         [0.67553191],
#         [0.13043478],
#         [0.10810811],
#         [0.97115385],
#         [0.14285714],
#         [0.36592681],
#         [0.14285714],
#         [0.78571429],
#         [0.72418848]],
#
#        [[0.07614213],
#         [0.00444444],
#         [0.2444235 ],
#         [0.24466718],
#         [0.71010638],
#         [0.52173913],
#         [0.27027027],
#         [0.77564103],
#         [0.14285714],
#         [0.35632873],
#         [0.28571429],
#         [0.70238095],
#         [0.60272251]],
#
#        [[0.08121827],
#         [0.45777778],
#         [0.27364122],
#         [0.15523002],
#         [0.85638298],
#         [0.39130435],
#         [0.25225225],
#         [0.78205128],
#         [0.32142857],
#         [0.34013197],
#         [0.57142857],
#         [0.63095238],
#         [0.53382199]],
#
#        [[0.08629442],
#         [0.29777778],
#         [0.19666981],
#         [0.14803392],
#         [0.68085106],
#         [0.26086957],
#         [0.15315315],
#         [1.        ],
#         [0.21428571],
#         [0.29694061],
#         [0.42857143],
#         [0.71428571],
#         [0.92314136]],
#
#        [[0.09137056],
#         [0.38666667],
#         [0.27552623],
#         [0.2076587 ],
#         [0.78191489],
#         [0.43478261],
#         [0.32432432],
#         [0.86217949],
#         [0.32142857],
#         [0.29574085],
#         [0.28571429],
#         [0.85714286],
#         [0.76230366]],
#
#        [[0.0964467 ],
#         [0.27555556],
#         [0.22651587],
#         [0.09637625],
#         [0.8856383 ],
#         [0.34782609],
#         [0.2972973 ],
#         [0.75320513],
#         [0.39285714],
#         [0.39712058],
#         [0.28571429],
#         [0.61904762],
#         [0.95979058]],
#
#        [[0.10152284],
#         [0.33777778],
#         [0.27301288],
#         [0.41711642],
#         [0.8643617 ],
#         [0.2173913 ],
#         [0.1981982 ],
#         [0.68269231],
#         [0.21428571],
#         [0.30293941],
#         [0.28571429],
#         [0.83333333],
#         [0.73633508]],
#
#        [[0.10659898],
#         [0.26222222],
#         [0.24599434],
#         [0.28887176],
#         [0.7606383 ],
#         [0.17391304],
#         [0.25225225],
#         [0.68589744],
#         [0.10714286],
#         [0.31973605],
#         [0.42857143],
#         [0.54761905],
#         [0.82806283]],
#
#        [[0.11167513],
#         [0.45777778],
#         [0.53377317],
#         [0.11205346],
#         [0.625     ],
#         [0.39130435],
#         [0.31531532],
#         [0.82051282],
#         [0.21428571],
#         [0.11277744],
#         [0.14285714],
#         [0.82142857],
#         [0.86010471]],
#
#        [[0.11675127],
#         [0.41333333],
#         [0.12629595],
#         [0.11745053],
#         [0.83244681],
#         [0.34782609],
#         [0.17117117],
#         [0.83653846],
#         [0.42857143],
#         [0.10137972],
#         [0.28571429],
#         [0.78571429],
#         [0.76230366]],
#
#        [[0.12182741],
#         [0.26666667],
#         [0.40182218],
#         [0.08892316],
#         [0.55053191],
#         [0.2173913 ],
#         [0.25225225],
#         [0.84935897],
#         [0.21428571],
#         [0.29334133],
#         [0.57142857],
#         [0.80952381],
#         [0.62890052]],
#
#        [[0.12690355],
#         [0.41777778],
#         [0.09267986],
#         [0.04446158],
#         [0.79255319],
#         [0.30434783],
#         [0.27027027],
#         [0.84935897],
#         [0.25      ],
#         [0.26154769],
#         [0.42857143],
#         [0.60714286],
#         [0.76314136]],
#
#        [[0.1319797 ],
#         [0.29333333],
#         [0.32296576],
#         [0.1765613 ],
#         [0.74468085],
#         [0.2173913 ],
#         [0.20720721],
#         [0.75      ],
#         [0.35714286],
#         [0.43071386],
#         [0.28571429],
#         [0.76190476],
#         [0.66680628]],
#
#        [[0.13705584],
#         [0.21333333],
#         [0.31825322],
#         [0.2845027 ],
#         [0.60106383],
#         [0.60869565],
#         [0.2972973 ],
#         [0.72435897],
#         [0.07142857],
#         [0.24355129],
#         [0.28571429],
#         [0.72619048],
#         [0.72188482]],
#
#        [[0.14213198],
#         [0.49777778],
#         [0.46182846],
#         [0.08326908],
#         [0.7393617 ],
#         [0.30434783],
#         [0.18918919],
#         [0.71794872],
#         [0.        ],
#         [0.24835033],
#         [0.14285714],
#         [0.72619048],
#         [0.73696335]],
#
#        [[0.14720812],
#         [0.36444444],
#         [0.44234998],
#         [0.30172192],
#         [0.79787234],
#         [0.17391304],
#         [0.10810811],
#         [0.95512821],
#         [0.39285714],
#         [0.26814637],
#         [0.42857143],
#         [0.82142857],
#         [0.33780105]],
#
#        [[0.15228426],
#         [0.29333333],
#         [0.25416274],
#         [0.3156001 ],
#         [0.74468085],
#         [0.30434783],
#         [0.04504505],
#         [0.69230769],
#         [0.25      ],
#         [0.25194961],
#         [0.42857143],
#         [0.72619048],
#         [0.64942408]],
#
#        [[0.15736041],
#         [0.36888889],
#         [0.40999057],
#         [0.09432023],
#         [0.58244681],
#         [0.2173913 ],
#         [0.27927928],
#         [0.93910256],
#         [0.32142857],
#         [0.11757648],
#         [0.42857143],
#         [0.83333333],
#         [0.70157068]]])]
# [array([0.83756345])]

# %%
def Data_format_conversion(Train_no,engine_id):    
    
    import pandas as pd
    import numpy as np
    df=pd.read_csv("Processed_Train_00{}.csv".format(Train_no))
    df = df[df['ID']==engine_id]
    df = df.drop(columns=['ID'])

    # Scalling the DATA
    scaler=MinMaxScaler()
    df = scaler.fit_transform(df)
    print('Shape of df for engine {}: '.format(engine_id),df.shape)

    # Getting into training shape with slidingwindow
    features = df[:,0:-1]
    target = df[:,-1]

    ts_generator = TimeseriesGenerator(features,target,length=win_length,sampling_rate=1,batch_size=1)

    # Changing the shape of input to (no of smaples,window_length,features)
    X=[]
    y=[]
    for i in range(len(ts_generator)):
        x_temp, y_temp = ts_generator[i]
        X.append(x_temp.reshape(x_temp.shape[1],x_temp.shape[2],1))
        y.append(y_temp)

    X=np.array(X)  
    y=np.array(y)  
    
    return(X,y,scaler,features)

# %% [markdown]
# # Training the CNN Model

# %%
win_length = 32   # Sliding Window Length
feature_num = 13  # Total number of features

# CNN
model=Sequential()
model.add(Conv2D(filters=64, kernel_size=3, activation='relu', input_shape=(win_length,feature_num,1)))
model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(1, activation='linear'))

model.compile(loss='mean_squared_error',optimizer='adam',metrics=['mean_squared_error'])
model.summary()
# Out:
# c:\Users\Subham Maurya\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 11, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 9, 32)      │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8064)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         8,065 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,169 (106.13 KB)
#  Trainable params: 27,169 (106.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fitting the training data with CNN
Train_no=1
for engine_no in range(1,101):    
    X,y,scaler,features=Data_format_conversion(Train_no,engine_no) 
    model.fit(X,y,steps_per_epoch=5,epochs=15,shuffle=False,verbose=0)
# Out:
# Shape of df for engine 1:  (192, 14)
# Shape of df for engine 2:  (287, 14)
# Shape of df for engine 3:  (179, 14)
# Shape of df for engine 4:  (189, 14)
# Shape of df for engine 5:  (269, 14)
# Shape of df for engine 6:  (188, 14)
# Shape of df for engine 7:  (259, 14)
# Shape of df for engine 8:  (150, 14)
# Shape of df for engine 9:  (201, 14)
# Shape of df for engine 10:  (222, 14)
# Shape of df for engine 11:  (240, 14)
# Shape of df for engine 12:  (170, 14)
# Shape of df for engine 13:  (163, 14)
# Shape of df for engine 14:  (180, 14)
# Shape of df for engine 15:  (207, 14)
# Shape of df for engine 16:  (209, 14)
# Shape of df for engine 17:  (276, 14)
# Shape of df for engine 18:  (195, 14)
# Shape of df for engine 19:  (158, 14)
# Shape of df for engine 20:  (234, 14)
# Shape of df for engine 21:  (195, 14)
# Shape of df for engine 22:  (202, 14)
# Shape of df for engine 23:  (168, 14)
# Shape of df for engine 24:  (147, 14)
# Shape of df for engine 25:  (230, 14)
# Shape of df for engine 26:  (199, 14)
# Shape of df for engine 27:  (156, 14)
# Shape of df for engine 28:  (165, 14)
# Shape of df for engine 29:  (163, 14)
# Shape of df for engine 30:  (194, 14)
# Shape of df for engine 31:  (234, 14)
# Shape of df for engine 32:  (191, 14)
# Shape of df for engine 33:  (200, 14)
# Shape of df for engine 34:  (195, 14)
# Shape of df for engine 35:  (181, 14)
# Shape of df for engine 36:  (158, 14)
# Shape of df for engine 37:  (170, 14)
# Shape of df for engine 38:  (194, 14)
# Shape of df for engine 39:  (128, 14)
# Shape of df for engine 40:  (188, 14)
# Shape of df for engine 41:  (216, 14)
# Shape of df for engine 42:  (196, 14)
# Shape of df for engine 43:  (207, 14)
# Shape of df for engine 44:  (192, 14)
# Shape of df for engine 45:  (158, 14)
# Shape of df for engine 46:  (256, 14)
# Shape of df for engine 47:  (214, 14)
# Shape of df for engine 48:  (231, 14)
# Shape of df for engine 49:  (215, 14)
# Shape of df for engine 50:  (198, 14)
# Shape of df for engine 51:  (213, 14)
# Shape of df for engine 52:  (213, 14)
# Shape of df for engine 53:  (195, 14)
# Shape of df for engine 54:  (257, 14)
# Shape of df for engine 55:  (193, 14)
# Shape of df for engine 56:  (275, 14)
# Shape of df for engine 57:  (137, 14)
# Shape of df for engine 58:  (147, 14)
# Shape of df for engine 59:  (231, 14)
# Shape of df for engine 60:  (172, 14)
# Shape of df for engine 61:  (185, 14)
# Shape of df for engine 62:  (180, 14)
# Shape of df for engine 63:  (174, 14)
# Shape of df for engine 64:  (283, 14)
# Shape of df for engine 65:  (153, 14)
# Shape of df for engine 66:  (202, 14)
# Shape of df for engine 67:  (313, 14)
# Shape of df for engine 68:  (199, 14)
# Shape of df for engine 69:  (362, 14)
# Shape of df for engine 70:  (137, 14)
# Shape of df for engine 71:  (208, 14)
# Shape of df for engine 72:  (213, 14)
# Shape of df for engine 73:  (213, 14)
# Shape of df for engine 74:  (166, 14)
# Shape of df for engine 75:  (229, 14)
# Shape of df for engine 76:  (210, 14)
# Shape of df for engine 77:  (154, 14)
# Shape of df for engine 78:  (231, 14)
# Shape of df for engine 79:  (199, 14)
# Shape of df for engine 80:  (185, 14)
# Shape of df for engine 81:  (240, 14)
# Shape of df for engine 82:  (214, 14)
# Shape of df for engine 83:  (293, 14)
# Shape of df for engine 84:  (267, 14)
# Shape of df for engine 85:  (188, 14)
# Shape of df for engine 86:  (278, 14)
# Shape of df for engine 87:  (178, 14)
# Shape of df for engine 88:  (213, 14)
# Shape of df for engine 89:  (217, 14)
# Shape of df for engine 90:  (154, 14)
# Shape of df for engine 91:  (135, 14)
# Shape of df for engine 92:  (341, 14)
# Shape of df for engine 93:  (155, 14)
# Shape of df for engine 94:  (258, 14)
# Shape of df for engine 95:  (283, 14)
# Shape of df for engine 96:  (336, 14)
# Shape of df for engine 97:  (202, 14)
# Shape of df for engine 98:  (156, 14)
# Shape of df for engine 99:  (185, 14)
# Shape of df for engine 100:  (200, 14)

# %% [markdown]
# # Loading the saved model

# %%
# from keras.models import load_model
 
# # load model
# model = load_model('model_1.h5')

# %% [markdown]
# # Predict on Training data

# %%
Train_no=1
engine_id = 1
X,y,scaler,features=Data_format_conversion(Train_no,engine_id)
# Out:
# Shape of df for engine 1:  (192, 14)

# %%
X.shape
# Out:
# (160, 32, 13, 1)

# %%
prediction=model.predict(X) ######### prediction on trained data
np.shape(prediction)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# (160, 1)

# %%
len(features)
# Out:
# 192

# %%
rev_trans =pd.concat([pd.DataFrame(features[win_length:]),pd.DataFrame(prediction)],axis=1)
rev_trans
# Out:
#            0      1         2         3         4        5         6   \
# 0    0.167539  0.400  0.387931  0.227273  0.917840  0.12500  0.192308
# 1    0.172775  0.332  0.139009  0.177196  0.845070  0.09375  0.338462
# 2    0.178010  0.292  0.445402  0.241911  0.845070  0.12500  0.215385
# 3    0.183246  0.332  0.147989  0.307139  0.899061  0.03125  0.169231
# 4    0.188482  0.112  0.054239  0.136620  0.922535  0.21875  0.200000
# ..        ...    ...       ...       ...       ...      ...       ...
# 155  0.979058  0.816  0.890086  0.749872  0.291080  0.96875  0.746154
# 156  0.984293  0.988  0.667026  0.884181  0.000000  0.84375  0.807692
# 157  0.989529  0.772  0.776580  0.831279  0.138498  0.90625  1.000000
# 158  0.994764  0.652  0.889368  0.826656  0.051643  0.87500  0.861538
# 159  1.000000  0.732  0.855244  0.863380  0.129108  1.00000  0.938462
#
#            7         8         9      10        11        12        0
# 0    0.714715  0.289474  0.045955  0.250  0.583333  0.724081  0.848594
# 1    0.651652  0.315789  0.431715  0.250  0.559524  0.647570  0.847789
# 2    0.666667  0.105263  0.484142  0.125  0.940476  0.845685  0.842015
# 3    0.837838  0.184211  0.365049  0.250  0.619048  0.872297  0.837502
# 4    0.828829  0.184211  0.297735  0.250  0.773810  0.880429  0.831107
# ..        ...       ...       ...    ...       ...       ...       ...
# 155  0.078078  0.684211  0.987055  0.750  0.202381  0.000000 -0.011140
# 156  0.015015  0.947368  0.971521  0.625  0.166667  0.284421 -0.019728
# 157  0.153153  1.000000  0.997411  1.000  0.178571  0.200887 -0.027866
# 158  0.012012  0.868421  0.965696  0.500  0.130952  0.315468 -0.037040
# 159  0.165165  0.921053  0.926214  0.750  0.166667  0.011273 -0.041709
#
# [160 rows x 14 columns]

# %%
rev_trans = scaler.inverse_transform(rev_trans) # Transforming back to original scale
rev_trans =pd.DataFrame(rev_trans)
rev_trans
# Out:
#         0       1        2        3       4        5      6       7        8   \
# 0     33.0  642.71  1588.40  1402.43  554.61  2388.04  47.28  521.91  2388.08
# 1     34.0  642.54  1581.47  1400.48  554.30  2388.03  47.47  521.70  2388.09
# 2     35.0  642.44  1590.00  1403.00  554.30  2388.04  47.31  521.75  2388.01
# 3     36.0  642.54  1581.72  1405.54  554.53  2388.01  47.25  522.32  2388.04
# 4     37.0  641.99  1579.11  1398.90  554.63  2388.07  47.29  522.29  2388.04
# ..     ...     ...      ...      ...     ...      ...    ...     ...      ...
# 155  188.0  643.75  1602.38  1422.78  551.94  2388.31  48.00  519.79  2388.23
# 156  189.0  644.18  1596.17  1428.01  550.70  2388.27  48.08  519.58  2388.33
# 157  190.0  643.64  1599.22  1425.95  551.29  2388.29  48.33  520.04  2388.35
# 158  191.0  643.34  1602.36  1425.77  550.92  2388.28  48.15  519.57  2388.30
# 159  192.0  643.54  1601.41  1427.20  551.25  2388.32  48.25  520.08  2388.32
#
#          9      10     11       12          13
# 0    8.3753  392.0  38.83  23.3506  162.081388
# 1    8.4349  392.0  38.81  23.3092  161.927617
# 2    8.4430  391.0  39.13  23.4164  160.824870
# 3    8.4246  392.0  38.86  23.4308  159.962871
# 4    8.4142  392.0  38.99  23.4352  158.741407
# ..      ...    ...    ...      ...         ...
# 155  8.5207  396.0  38.51  22.9588   -2.127772
# 156  8.5183  395.0  38.48  23.1127   -3.767983
# 157  8.5223  398.0  38.49  23.0675   -5.322441
# 158  8.5174  394.0  38.45  23.1295   -7.074582
# 159  8.5113  396.0  38.48  22.9649   -7.966375
#
# [160 rows x 14 columns]

# %%
    
df=pd.read_csv("Processed_Train_00{}.csv".format(Train_no))
df = df[df['ID']==engine_id]
df_actual = df.drop(columns=['ID'])
df_actual
# Out:
#      Cycle  SensorMeasure2  SensorMeasure3  SensorMeasure4  SensorMeasure7  \
# 0        1          641.82         1589.70         1400.60          554.36
# 1        2          642.15         1591.82         1403.14          553.75
# 2        3          642.35         1587.99         1404.20          554.26
# 3        4          642.35         1582.79         1401.87          554.45
# 4        5          642.37         1582.85         1406.22          554.00
# ..     ...             ...             ...             ...             ...
# 187    188          643.75         1602.38         1422.78          551.94
# 188    189          644.18         1596.17         1428.01          550.70
# 189    190          643.64         1599.22         1425.95          551.29
# 190    191          643.34         1602.36         1425.77          550.92
# 191    192          643.54         1601.41         1427.20          551.25
#
#      SensorMeasure8  SensorMeasure11  SensorMeasure12  SensorMeasure13  \
# 0           2388.06            47.47           521.66          2388.02
# 1           2388.04            47.49           522.28          2388.07
# 2           2388.08            47.27           522.42          2388.03
# 3           2388.11            47.13           522.86          2388.08
# 4           2388.06            47.28           522.19          2388.04
# ..              ...              ...              ...              ...
# 187         2388.31            48.00           519.79          2388.23
# 188         2388.27            48.08           519.58          2388.33
# 189         2388.29            48.33           520.04          2388.35
# 190         2388.28            48.15           519.57          2388.30
# 191         2388.32            48.25           520.08          2388.32
#
#      SensorMeasure15  SensorMeasure17  SensorMeasure20  SensorMeasure21  RUL
# 0             8.4195              392            39.06          23.4190  191
# 1             8.4318              392            39.00          23.4236  190
# 2             8.4178              390            38.95          23.3442  189
# 3             8.3682              392            38.88          23.3739  188
# 4             8.4294              393            38.90          23.4044  187
# ..               ...              ...              ...              ...  ...
# 187           8.5207              396            38.51          22.9588    4
# 188           8.5183              395            38.48          23.1127    3
# 189           8.5223              398            38.49          23.0675    2
# 190           8.5174              394            38.45          23.1295    1
# 191           8.5113              396            38.48          22.9649    0
#
# [192 rows x 14 columns]

# %%
print('RMSE on This set:', np.sqrt(metrics.mean_squared_error(df_actual['RUL'][win_length:],rev_trans[13])))
# Out:
# RMSE on This set: 3.8776430622460882

# %%
plt.plot(df_actual['Cycle'][win_length:],df_actual['RUL'][win_length:])
plt.plot(rev_trans[0],rev_trans[13])
plt.ylabel('RUL')
plt.xlabel('CYCLE')
plt.title('Engine No is: {}'.format(engine_id))
plt.legend([ 'Actual','Prediction'], loc='upper right')
plt.show()
print('\n')

# %%
Train_no=1
m = np.random.randint(low=1,high=100,size=5) 

for i in m:    
    engine_id=i
    X,y,scaler,features=Data_format_conversion(Train_no,engine_id) 

    prediction=model.predict(X) # prediction on trained data
    rev_trans =pd.concat([pd.DataFrame(features[win_length:]),pd.DataFrame(prediction)],axis=1)
    rev_trans = scaler.inverse_transform(rev_trans)# Transforming back to original scale
    rev_trans =pd.DataFrame(rev_trans)

    
    df=pd.read_csv("Processed_Train_00{}.csv".format(Train_no))
    df = df[df['ID']==engine_id]
    df_actual = df.drop(columns=['ID'])


    print('RMSE on This set:', np.sqrt(metrics.mean_squared_error(df_actual['RUL'][win_length:],rev_trans[13])))

    plt.plot(df_actual['Cycle'][win_length:],df_actual['RUL'][win_length:])
    plt.plot(rev_trans[0],rev_trans[13])
    plt.ylabel('RUL')
    plt.xlabel('CYCLE')
    plt.title('Engine No is: {}'.format(engine_id))
    plt.legend([ 'Actual','Prediction'], loc='upper right')
    plt.show()
    print('\n')
# Out:
# Shape of df for engine 89:  (217, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# RMSE on This set: 8.556214778591908
# Shape of df for engine 1:  (192, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RMSE on This set: 3.8776430622460882
# Shape of df for engine 26:  (199, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RMSE on This set: 6.152233363877956
# Shape of df for engine 10:  (222, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# RMSE on This set: 3.885588255306341
# Shape of df for engine 35:  (181, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RMSE on This set: 3.630111471961394

# %%
# # save model and architecture to single file
# model.save("cnn_model.h5")
# print("Saved model to disk")

# %%
Train_no = 1
ans = 0

for i in range(1, 101):    
    engine_id=i
    X,y,scaler,features=Data_format_conversion(Train_no,engine_id) 

    prediction=model.predict(X) # prediction on trained data
    rev_trans =pd.concat([pd.DataFrame(features[win_length:]),pd.DataFrame(prediction)],axis=1)
    rev_trans = scaler.inverse_transform(rev_trans)# Transforming back to original scale
    rev_trans =pd.DataFrame(rev_trans)

    df=pd.read_csv("Processed_Train_00{}.csv".format(Train_no))
    df = df[df['ID']==engine_id]
    df_actual = df.drop(columns=['ID'])

    ans += np.sqrt(metrics.mean_squared_error(df_actual['RUL'][win_length:],rev_trans[13]))


print('Average RMSE:', ans/100)
# Out:
# Shape of df for engine 1:  (192, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Shape of df for engine 2:  (287, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 3:  (179, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 4:  (189, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 5:  (269, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 6:  (188, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 7:  (259, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 8:  (150, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 9:  (201, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 10:  (222, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Shape of df for engine 11:  (240, 14)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 12:  (170, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 13:  (163, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 14:  (180, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Shape of df for engine 15:  (207, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 16:  (209, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Shape of df for engine 17:  (276, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 18:  (195, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 19:  (158, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 20:  (234, 14)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Shape of df for engine 21:  (195, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 22:  (202, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 23:  (168, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 24:  (147, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Shape of df for engine 25:  (230, 14)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 26:  (199, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 27:  (156, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 28:  (165, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 29:  (163, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 30:  (194, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 31:  (234, 14)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 32:  (191, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 33:  (200, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Shape of df for engine 34:  (195, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 35:  (181, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Shape of df for engine 36:  (158, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 37:  (170, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 38:  (194, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 39:  (128, 14)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Shape of df for engine 40:  (188, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Shape of df for engine 41:  (216, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 42:  (196, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 43:  (207, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 44:  (192, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 45:  (158, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Shape of df for engine 46:  (256, 14)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Shape of df for engine 47:  (214, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 48:  (231, 14)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 49:  (215, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 50:  (198, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 51:  (213, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 52:  (213, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Shape of df for engine 53:  (195, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 54:  (257, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 55:  (193, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 56:  (275, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 57:  (137, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Shape of df for engine 58:  (147, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 59:  (231, 14)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 60:  (172, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 61:  (185, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Shape of df for engine 62:  (180, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 63:  (174, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Shape of df for engine 64:  (283, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 65:  (153, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 66:  (202, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 67:  (313, 14)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Shape of df for engine 68:  (199, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Shape of df for engine 69:  (362, 14)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Shape of df for engine 70:  (137, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 71:  (208, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 72:  (213, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 73:  (213, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 74:  (166, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 75:  (229, 14)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Shape of df for engine 76:  (210, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 77:  (154, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Shape of df for engine 78:  (231, 14)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 79:  (199, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 80:  (185, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 81:  (240, 14)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Shape of df for engine 82:  (214, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 83:  (293, 14)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 84:  (267, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Shape of df for engine 85:  (188, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 86:  (278, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 87:  (178, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 88:  (213, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 89:  (217, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 90:  (154, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Shape of df for engine 91:  (135, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 92:  (341, 14)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Shape of df for engine 93:  (155, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Shape of df for engine 94:  (258, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Shape of df for engine 95:  (283, 14)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 96:  (336, 14)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 97:  (202, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Shape of df for engine 98:  (156, 14)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Shape of df for engine 99:  (185, 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Shape of df for engine 100:  (200, 14)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Average RMSE: 6.186373393560379
